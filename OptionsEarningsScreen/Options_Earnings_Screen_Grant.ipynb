# %%
#Look for tickers with upcoming earnings(max days in advance parameter)

#Look at HV/IV ratio, look for absolue IV

#Compare expected move to historical moves
  #Expected move, find nearest expiry compute 1D straddle
    #1 day straddle calculation look at days and hours (if current time is within trading day)

#Have option to add constraints
  #HV/IV
  #Absolute IV
  #Liquidity constraints (B-A/Premium)
  #Premium constraints
  #Earnings performance of similar stocks

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime, time, timedelta
import requests

from pandas.tseries.holiday import AbstractHolidayCalendar, Holiday, nearest_workday, \
    USMartinLutherKingJr, USPresidentsDay, GoodFriday, USMemorialDay, \
    USLaborDay, USThanksgivingDay

import yfinanceHelper as yfh
import FinanceTools as ft
import FinanceScrapers as fs
import CalendarTools as ct
import OptionsEarningsTools as oet

# %%
oet.getEarningsScreen('GME', earningsTime='PM', displayEarningsTable=False)
# Out:
# /Users/grantlau/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/yfinance/base.py:2093: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_html(data)[0]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/pandas/compat/_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:666, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap>:565, in module_from_spec(spec)
#
# File <frozen importlib._bootstrap_external>:1173, in create_module(self, spec)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# ImportError: dlopen(/Users/grantlau/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/lxml/etree.cpython-39-darwin.so, 0x0002): symbol not found in flat namespace '_exsltDateXpathCtxtRegister'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /Users/grantlau/Documents/QuantStuff/Volatility/OptionsEarningsScreen/Options_Earnings_Screen_Grant.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/grantlau/Documents/QuantStuff/Volatility/OptionsEarningsScreen/Options_Earnings_Screen_Grant.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> oet.getEarningsScreen('GME', earningsTime='PM', displayEarningsTable=False)
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:72, in getEarningsScreen(ticker, earningsTime, displayEarningsTable)
#      70 def getEarningsScreen(ticker, earningsTime = 'PM', displayEarningsTable = False):
#      71   yfTicker = yfh.getYfTicker(ticker)
# ---> 72   earningsTable = getEarningsTable(yfTicker, earningsTime = earningsTime)
#      73   print(earningsTable)
#      74   avgAbs1DMove = earningsTable['1D Move'].abs().mean()
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:44, in getEarningsTable(yfTicker, earningsTime)
#      43 def getEarningsTable(yfTicker, earningsTime = 'PM'):
# ---> 44   yfEarningsDates = yfTicker.earnings_dates
#      45   #Get at least 8 previous quarters of earnings if possible
#      46   if yfEarningsDates['Reported EPS'].count()<8:
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/yfinance/ticker.py:256, in Ticker.earnings_dates(self)
#     254 @property
#     255 def earnings_dates(self) -> _pd.DataFrame:
# --> 256     return self.get_earnings_dates()
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/yfinance/utils.py:114, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     111 logger.debug(f'Entering {func.__name__}()')
#     113 with IndentationContext():
# --> 114     result = func(*args, **kwargs)
#     116 logger.debug(f'Exiting {func.__name__}()')
#     117 return result
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/yfinance/base.py:2093, in TickerBase.get_earnings_dates(self, limit, proxy)
#    2088     raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#    2089                        "Our engineers are working quickly to resolve "
#    2090                        "the issue. Thank you for your patience.")
#    2092 try:
# -> 2093     data = pd.read_html(data)[0]
#    2094 except ValueError:
#    2095     if page_offset == 0:
#    2096         # Should not fail on first page
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/pandas/io/html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
#    1246     flavor=flavor,
#    1247     io=io,
#    1248     match=match,
#    1249     header=header,
#    1250     index_col=index_col,
#    1251     skiprows=skiprows,
#    1252     parse_dates=parse_dates,
#    1253     thousands=thousands,
#    1254     attrs=attrs,
#    1255     encoding=encoding,
#    1256     decimal=decimal,
#    1257     converters=converters,
#    1258     na_values=na_values,
#    1259     keep_default_na=keep_default_na,
#    1260     displayed_only=displayed_only,
#    1261     extract_links=extract_links,
#    1262     dtype_backend=dtype_backend,
#    1263     storage_options=storage_options,
#    1264 )
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/pandas/io/html.py:976, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     974 retained = None
#     975 for flav in flavor:
# --> 976     parser = _parser_dispatch(flav)
#     977     p = parser(
#     978         io,
#     979         compiled_match,
#    (...)
#     984         storage_options,
#     985     )
#     987     try:
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/pandas/io/html.py:923, in _parser_dispatch(flavor)
#     921     import_optional_dependency("bs4")
#     922 else:
# --> 923     import_optional_dependency("lxml.etree")
#     924 return _valid_parsers[flavor]
#
# File ~/Documents/Fall2023/APS502/PythonFiles/.venv/lib/python3.9/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     133 except ImportError:
#     134     if errors == "raise":
# --> 135         raise ImportError(msg)
#     136     return None
#     138 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'lxml'.  Use pip or conda to install lxml.

# %%
def getSigmaForward(sigma_1, sigma_2, t_1, t_2):
  return np.sqrt((sigma_2**2*t_2-sigma_1**2*t_1)/(t_2-t_1))

def getExpectedDailyMove(yfTicker, nextEarningsDate, startDate = datetime.today()):
  #https://www.trading-volatility.com/Trading-Volatility.pdf - Chapter 6.4
  #Note T is in trading days not years here
  expiries = tuple(datetime.strptime(date_str, "%Y-%m-%d") for date_str in yfTicker.options)
  expiries = tuple(datetime.combine(expiry.date(), time(16,0)) for expiry in expiries)
  expiryIndex_T1 = min(range(len(expiries)), key=lambda i: (expiries[i] < nextEarningsDate, abs(expiries[i] - nextEarningsDate)))
  expiry_T1 = expiries[expiryIndex_T1]

  callChain_T1, putChain_T1, underlyingInfo_T1 = yfh.getYfOptionChain(yfTicker, expiry_T1)
  sigma_T1 = yfh.getYfImpliedVol(callChain_T1, putChain_T1, underlyingInfo_T1, underlyingInfo_T1['regularMarketPrice'])
  T1 = ct.tradingDaysToExpiry(expiryDate = expiry_T1, startDate = startDate) #TODO calculate time in days between today and expiry_jump

  if expiryIndex_T1 > 0: #expiry exists before earnings, use T0 to calculate sigma_diffusive
    expiryIndex_T0 = expiryIndex_T1 - 1
    expiry_T0 = expiries[expiryIndex_T0]
    callChain_T0, putChain_T0, underlyingInfo_T0 = yfh.getYfOptionChain(yfTicker, expiry_T0)
    sigma_diffusive = yfh.getYfImpliedVol(callChain_T0, putChain_T0, underlyingInfo_T0, underlyingInfo_T0['regularMarketPrice'])
  else: #Earnings expiry is closest expiry, use T2 and forward implied vol to calculate sigma_diffusive
    expiryIndex_T2 = expiryIndex_T1+1
    expiry_T2 = expiries[expiryIndex_T2]
    callChain_T2, putChain_T2, underlyingInfo_T2 = yfh.getYfOptionChain(yfTicker, expiry_T2)
    sigma_T2 = yfh.getYfImpliedVol(callChain_T2, putChain_T2, underlyingInfo_T2, underlyingInfo_T2['regularMarketPrice'])
    T2 = ct.tradingDaysToExpiry(expiryDate = expiry_T2, startDate = startDate)
    sigma_diffusive = getSigmaForward(sigma_T1, sigma_T2, T1, T2)
  sigma_jump = np.sqrt(sigma_T1**2*T1-sigma_diffusive**2*(T1-1))

  expectedDailyMove = sigma_jump/np.sqrt(252)
  #TODO normalize for (subtract) index term structure
  return expectedDailyMove

# %%
def getEarningsScreen(ticker, earningsTime = 'PM', displayEarningsTable = False):
  yfTicker = yfh.getYfTicker(ticker)
  earningsTable = getEarningsTable(yfTicker, earningsTime = earningsTime)
  avgAbs1DMove = earningsTable['1D Move'].abs().mean()
  positive1DMoves = (earningsTable['1D Move']>0).sum()
  reportedQuarters = earningsTable['Reported EPS'].count()
  today = datetime.today()
  nextEarningsIndex = min(range(len(earningsTable.index)), key=lambda i: (earningsTable.index[i] < today, abs(earningsTable.index[i] - today)))
  nextEarningsDate = earningsTable.index[nextEarningsIndex]
  implied1DMove = getExpectedDailyMove(yfTicker, nextEarningsDate)
  data = {
      'Symbol': [yfTicker.info['symbol']],
      'CurrentPrice': [yfTicker.info['currentPrice']],
      'EarningsDate': [nextEarningsDate.date()],
      'EarningsTime': [earningsTime],
      'AvgAbs1DMove': [avgAbs1DMove],
      'Implied1DMove': [implied1DMove],
      'Positive1DMoves': [positive1DMoves],
      'ReportedQuarters': [reportedQuarters]
  }
  earningsScreenDF = pd.DataFrame(data)
  if displayEarningsTable:
    display(earningsTable)
  return earningsScreenDF

def getEarningsTable(yfTicker, earningsTime = 'PM'):
  yfEarningsDates = yfTicker.earnings_dates
  #Get at least 8 previous quarters of earnings if possible
  if yfEarningsDates['Reported EPS'].count()<8:
    rowsNeeded = len(yfEarningsDates)+8-yfEarningsDates['Reported EPS'].count()
    yfEarningsDates = yfTicker.get_earnings_dates(limit = rowsNeeded)

  yfEarningsDates = yfEarningsDates.tz_localize(None)
  if earningsTime == 'AM':
    yfEarningsDates.index = yfEarningsDates.index.map(lambda x: x.replace(hour=9, minute=0, second=0, microsecond=0))
  else:
    yfEarningsDates.index = yfEarningsDates.index.map(lambda x: x.replace(hour=17, minute=0, second=0, microsecond=0))
  firstEarningsDate = yfEarningsDates.index[-1]
  yfHistory = yfh.getYfHistory(yfTicker, ct.getPreviousTradingDay(firstEarningsDate))
  spx_yfHistory = yfh.getYfHistory(yfh.getYfTicker('^SPX'), ct.getPreviousTradingDay(firstEarningsDate))
  if earningsTime == "AM":
    subsequentLogReturns = ft.getLogReturns(yfHistory['Close']).shift(0)
    spx_subsequentLogReturns = ft.getLogReturns(spx_yfHistory['Close']).shift(0)
  else: #earningsTime == 'PM'
    subsequentLogReturns = ft.getLogReturns(yfHistory['Close']).shift(-1) #-1
    spx_subsequentLogReturns = ft.getLogReturns(spx_yfHistory['Close']).shift(-1)
  oneDayMoves = pd.merge(yfEarningsDates, subsequentLogReturns, left_on=yfEarningsDates.index.date, right_on=subsequentLogReturns.index.date, how = 'left')['Close']
  spx_oneDayMoves = pd.merge(yfEarningsDates, spx_subsequentLogReturns, left_on=yfEarningsDates.index.date, right_on=spx_subsequentLogReturns.index.date, how = 'left')['Close']
  yfEarningsDates['1D Move'] = oneDayMoves.values
  yfEarningsDates['SPX 1D Move'] = spx_oneDayMoves.values
  return yfEarningsDates

def getUpcomingEarnings(startDate, endDate, minMarketCap = None, universe = None):
  earningsCal = fs.scrapeEarningsCalendar(startDate, endDate, minMarketCap)
  if universe != None:
    indexDF = fs.scrapeIndex(universe)
    earningsCal = pd.merge(earningsCal, indexDF, left_on='symbol', right_on='Ticker', how='inner')
  earningsScreens = []
  for index, row in earningsCal.iterrows():
    earningsTime = "AM" if row['time'] == 'time-pre-market' else "PM"
    earningsScreens.append(getEarningsScreen(row['symbol'], earningsTime))
  upcomingEarnings = pd.concat(earningsScreens, ignore_index=True)
  return upcomingEarnings

# %%
getEarningsScreen('GME', earningsTime='PM', displayEarningsTable=True)
# Out:
#                      EPS Estimate  Reported EPS  Surprise(%)   1D Move  \
# Earnings Date
# 2024-12-04 17:00:00           NaN           NaN          NaN       NaN
# 2024-09-04 17:00:00           NaN           NaN          NaN       NaN
# 2024-06-05 17:00:00           NaN           NaN          NaN       NaN
# 2024-03-19 17:00:00          0.28           NaN          NaN       NaN
# 2024-03-19 17:00:00          0.28           NaN          NaN       NaN
# 2023-12-06 17:00:00         -0.09           NaN       1.0000  0.097513
# 2023-12-05 17:00:00         -0.08           NaN       1.0000 -0.004706
# 2023-09-06 17:00:00         -0.14         -0.03       0.7877  0.007439
# 2023-06-07 17:00:00         -0.12         -0.14      -0.1667 -0.197060
# 2023-03-21 17:00:00         -0.13          0.16       2.2030  0.301887
# 2022-12-07 17:00:00         -0.28         -0.31      -0.1205  0.107649
# 2022-09-07 17:00:00         -0.38         -0.35       0.0728  0.071817
# 2022-06-01 17:00:00         -0.36         -0.52      -0.4345  0.098749
# 2022-03-17 17:00:00          0.21         -0.46      -3.2208  0.034627
# 2021-12-08 17:00:00         -0.13         -0.35      -1.6861 -0.108725
#
#                      SPX 1D Move
# Earnings Date
# 2024-12-04 17:00:00          NaN
# 2024-09-04 17:00:00          NaN
# 2024-06-05 17:00:00          NaN
# 2024-03-19 17:00:00          NaN
# 2024-03-19 17:00:00          NaN
# 2023-12-06 17:00:00     0.007937
# 2023-12-05 17:00:00    -0.003914
# 2023-09-06 17:00:00    -0.003216
# 2023-06-07 17:00:00     0.006170
# 2023-03-21 17:00:00    -0.016600
# 2022-12-07 17:00:00     0.007494
# 2022-09-07 17:00:00     0.006589
# 2022-06-01 17:00:00     0.018263
# 2022-03-17 17:00:00     0.011595
# 2021-12-08 17:00:00    -0.007207
#   Symbol  CurrentPrice EarningsDate EarningsTime  AvgAbs1DMove  Implied1DMove  \
# 0    GME         18.12   2024-03-19           PM      0.103017       0.152346
#
#    Positive1DMoves  ReportedQuarters
# 0                7                 8

# %%
startDate = datetime.today()
endDate = datetime.today()+timedelta(days=30)
minMarketCap = 100000000000
earningsCalendar = fs.scrapeEarningsCalendar(startDate, endDate, minMarketCap)

# %%
earningsCalendar
# Out:
#    lastYearRptDt  lastYearEPS               time symbol  \
# 0      1/12/2023         1.82  time-not-supplied    TSM
# 1      1/13/2023         3.57    time-pre-market    JPM
# 2      1/13/2023         5.34    time-pre-market    UNH
# 3      1/13/2023         0.85    time-pre-market    BAC
# 4      1/13/2023         0.67    time-pre-market    WFC
# ..           ...          ...                ...    ...
# 60     2/02/2023         1.87  time-not-supplied   SONY
# 61     2/02/2023         0.75  time-not-supplied   SBUX
# 62     2/02/2023         0.06  time-not-supplied   MUFG
# 63     2/02/2023         1.67  time-not-supplied   GILD
# 64     2/02/2023         1.82    time-pre-market    BMY
#
#                                                name     marketCap  \
# 0   Taiwan Semiconductor Manufacturing Company Ltd.  5.393519e+11
# 1                             J P Morgan Chase & Co  4.917605e+11
# 2                   UnitedHealth Group Incorporated  4.869454e+11
# 3                       Bank of America Corporation  2.664554e+11
# 4                             Wells Fargo & Company  1.787493e+11
# ..                                              ...           ...
# 60                           Sony Group Corporation  1.176590e+11
# 61                            Starbucks Corporation  1.064747e+11
# 62               Mitsubishi UFJ Financial Group Inc  1.054874e+11
# 63                            Gilead Sciences, Inc.  1.037205e+11
# 64                     Bristol-Myers Squibb Company  1.073538e+11
#
#    fiscalQuarterEnding  epsForecast  noOfEsts               earningsDate
# 0             Dec/2023         1.34       3.0 2024-01-11 01:05:48.829528
# 1             Dec/2023         3.64      12.0 2024-01-12 01:05:48.829528
# 2             Dec/2023         5.98      11.0 2024-01-12 01:05:48.829528
# 3             Dec/2023         0.68      12.0 2024-01-12 01:05:48.829528
# 4             Dec/2023         1.16       9.0 2024-01-12 01:05:48.829528
# ..                 ...          ...       ...                        ...
# 60            Dec/2023         1.65       4.0 2024-02-01 01:05:48.829528
# 61            Dec/2023         0.95      12.0 2024-02-01 01:05:48.829528
# 62            Dec/2023          NaN       NaN 2024-02-01 01:05:48.829528
# 63            Dec/2023         1.78      12.0 2024-02-01 01:05:48.829528
# 64            Dec/2023         1.73      10.0 2024-02-02 01:05:48.829528
#
# [65 rows x 10 columns]

# %%
oet.getSigmaForward(0.2, 0.4, 10, 12)
# Out:
# 0.8717797887081348

# %%
yfTicker.news
# Out:
# [{'uuid': '1a65cc97-50cd-36fc-95ea-d081f9170c90',
#   'title': 'Where Will Walgreens Boots Alliance Be in 1 Year?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/1a65cc97-50cd-36fc-95ea-d081f9170c90/where-will-walgreens-boots.html',
#   'providerPublishTime': 1703171700,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Y3B4Hiv8IWf.ipxAfoOfFQ--~B/aD03MjA7dz0xMDc4O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/bb7badbe92e86a3ccad78c6d2b3cb143',
#      'width': 1078,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MO53ikaM9pDdiwL2w49.wQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/bb7badbe92e86a3ccad78c6d2b3cb143',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WBA']},
#  {'uuid': '93dc94ef-1dd8-35dc-8bcd-f3bc859735ad',
#   'title': 'Walgreens marketing chief let go amid last month’s layoffs',
#   'publisher': 'Retail Dive',
#   'link': 'https://finance.yahoo.com/m/93dc94ef-1dd8-35dc-8bcd-f3bc859735ad/walgreens-marketing-chief-let.html',
#   'providerPublishTime': 1703158200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/7L5vvJbIb7i2yzLaitKVSw--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/retail_dive_367/e40dcd68007900145781468cea313f83',
#      'width': 1280,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/XSr3Qj9VmEY8p.wX9Un4kg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/retail_dive_367/e40dcd68007900145781468cea313f83',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WBA']},
#  {'uuid': 'c8bc7c98-bb8c-3c4e-8de8-9524a13ea869',
#   'title': 'Walgreens’s Ambitions Lean on Its Technology. First, It Has to Build Up Its IT Department.',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/c8bc7c98-bb8c-3c4e-8de8-9524a13ea869/walgreens%E2%80%99s-ambitions-lean-on.html',
#   'providerPublishTime': 1703073600,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/6T3_JETMGv3Ygh3QyNSYsA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/03ff60aabc5bd1a0e433522bac7edec1',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/pNutJuts3kCnHTnDAcwRUA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/03ff60aabc5bd1a0e433522bac7edec1',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WBA']},
#  {'uuid': 'b0a8b05f-0d0b-30b2-a384-7ce937102b9f',
#   'title': "Dow Jones Industrial Average Posts 9th Straight Gain, Nasdaq Ends Above 15,000; Is It Time To Buy These 'Dogs Of The Dow'?",
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/b0a8b05f-0d0b-30b2-a384-7ce937102b9f/dow-jones-industrial-average.html',
#   'providerPublishTime': 1703021088,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/1fVVkGROB3AnNMu6aPljFA--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/5b1dc2d46870b045545d5e32ffa2764d',
#      'width': 1012,
#      'height': 572,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/W3IvwzSn.o9pZZE8OerM_Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/5b1dc2d46870b045545d5e32ffa2764d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'WBA', 'DIS']},
#  {'uuid': '7dd04a26-0748-3ae8-a5d1-d7eaa02cd3d7',
#   'title': 'Lawsuits claiming Tylenol causes autism lack scientific support, judge finds',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/lawsuits-claiming-tylenol-causes-autism-205226866.html',
#   'providerPublishTime': 1703019146,
#   'type': 'STORY',
#   'relatedTickers': ['JNJ', 'WBA', 'WMT']},
#  {'uuid': '13b22886-7a0d-3bba-821b-0950acb72f64',
#   'title': 'Walgreens Boots Alliance (WBA) Stock Dips While Market Gains: Key Facts',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/walgreens-boots-alliance-wba-stock-225018694.html',
#   'providerPublishTime': 1702939818,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Fj4TPQveJWuth16WIsEVAw--~B/aD01OTQ7dz05MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/46ebfcbff417ac1bbde85ad33fa0d4be',
#      'width': 900,
#      'height': 594,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/UfNPsRi0m54aItY_qLFDbg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/46ebfcbff417ac1bbde85ad33fa0d4be',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WBA']},
#  {'uuid': 'dec8c545-1553-3718-8a9b-1d1f61488b83',
#   'title': 'Should You Buy the 3 Highest-Paying Dividend Stocks in the Dow Jones?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/dec8c545-1553-3718-8a9b-1d1f61488b83/should-you-buy-the-3.html',
#   'providerPublishTime': 1702907100,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/I0G.UQU3hiIy0hZF3_DaDw--~B/aD03MjA7dz0xMDYwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f058b53359ba33ac95a34bafea19811f',
#      'width': 1060,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/r8NNbALMimj_f6UIQ27FeQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f058b53359ba33ac95a34bafea19811f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['VZ', '^DJI', 'WBA', 'MMM']},
#  {'uuid': '98e97133-3ebe-31ec-912f-c207f20ebe0d',
#   'title': 'A $1.3 Trillion Debt-Fueled Boom in Deals Faces a Grim New Reality',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/1-3-trillion-debt-fueled-000005242.html',
#   'providerPublishTime': 1702857605,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Vs9RlWDxMyiG224r4mEMVg--~B/aD05MTQ7dz0xMjk2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/4fe4722bb99a7652290874970a71dc76',
#      'width': 1296,
#      'height': 914,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/GLntymGiJGhZ.0din9IaWQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/4fe4722bb99a7652290874970a71dc76',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['WBA', 'BAYRY', 'PLD', 'ORCL', 'SAP', 'BUD', 'SPGI']}]
