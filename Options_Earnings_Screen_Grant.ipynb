# %%
#Look for tickers with upcoming earnings(max days in advance parameter)

#Look at HV/IV ratio, look for absolue IV

#Compare expected move to historical moves
  #Expected move, find nearest expiry compute 1D straddle
    #1 day straddle calculation look at days and hours (if current time is within trading day)

#Have option to add constraints
  #HV/IV
  #Absolute IV
  #Liquidity constraints (B-A/Premium)
  #Premium constraints
  #Earnings performance of similar stocks

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.4.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: yfinance in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: lxml in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in ./.venv/lib/python3.13/site-packages (from yfinance->-r requirements.txt (line 3)) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in ./.venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in ./.venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance->-r requirements.txt (line 3)) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance->-r requirements.txt (line 3)) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.13/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance->-r requirements.txt (line 3)) (3.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '/OptionsEarningsScreen')

import OptionsEarningsTools as oet
import FinanceScrapers as fs
import FinanceTools as ft
import yfinanceHelper as yfh

# %%
oet.getEarningsScreen('AMAT', earningsTime='PM', displayEarningsTable=True)
# Out:
# /Users/grantlau/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:21: RuntimeWarning: invalid value encountered in sqrt
#   #Note T is in trading days not years here
#                      EPS Estimate  Reported EPS  Surprise(%)   1D Move  \
# Earnings Date
# 2026-02-12 17:00:00          2.21           NaN          NaN       NaN
# 2025-11-13 17:00:00          2.09          2.17         3.65  0.012377
# 2025-08-14 17:00:00          2.36          2.48         5.13 -0.151604
# 2025-05-15 17:00:00          2.31          2.39         3.45 -0.053962
# 2025-02-13 17:00:00          2.30          2.38         3.67 -0.085321
# 2024-11-14 17:00:00          2.15          2.09        -2.98 -0.096558
# 2024-08-15 17:00:00          2.03          2.12         4.68 -0.018727
# 2024-05-16 17:00:00          1.99          2.09         5.27 -0.009153
# 2024-02-15 17:00:00          1.91          2.13        11.78  0.061533
# 2023-11-16 17:00:00          1.99          2.12         6.44 -0.041008
# 2023-08-17 17:00:00          1.75          1.90         8.88  0.036186
# 2023-05-18 17:00:00          1.83          2.00         9.49 -0.023125
# 2023-02-16 17:00:00          1.92          2.03         5.68  0.000433
# 2022-11-17 17:00:00          1.74          2.03        16.87  0.002391
# 2022-08-18 17:00:00          1.78          1.94         8.69 -0.034198
# 2022-05-19 17:00:00          1.90          1.85        -2.77 -0.039416
# 2022-02-16 17:00:00          1.85          1.89         1.89 -0.032371
# 2021-11-18 17:00:00          1.96          1.94        -0.93 -0.056432
# 2021-08-19 17:00:00          1.78          1.90         6.82 -0.015601
# 2021-05-20 17:00:00          1.51          1.63         7.92 -0.012743
# 2021-02-18 17:00:00          1.28          1.39         8.75  0.051796
# 2020-11-12 17:00:00          1.17          1.25         6.71  0.042220
# 2020-08-13 17:00:00          0.95          1.06        11.88  0.038440
# 2020-05-14 17:00:00          0.89          0.89         0.40 -0.044903
# 2020-02-12 17:00:00          0.93          0.98         5.82  0.030136
#
#                      SPX 1D Move
# Earnings Date
# 2026-02-12 17:00:00          NaN
# 2025-11-13 17:00:00    -0.000502
# 2025-08-14 17:00:00    -0.002901
# 2025-05-15 17:00:00     0.006981
# 2025-02-13 17:00:00    -0.000072
# 2024-11-14 17:00:00    -0.013291
# 2024-08-15 17:00:00     0.001988
# 2024-05-16 17:00:00     0.001164
# 2024-02-15 17:00:00    -0.004815
# 2023-11-16 17:00:00     0.001281
# 2023-08-17 17:00:00    -0.000149
# 2023-05-18 17:00:00    -0.001447
# 2023-02-16 17:00:00    -0.002771
# 2022-11-17 17:00:00     0.004747
# 2022-08-18 17:00:00    -0.012984
# 2022-05-19 17:00:00     0.000146
# 2022-02-16 17:00:00    -0.021401
# 2021-11-18 17:00:00    -0.001400
# 2021-08-19 17:00:00     0.008109
# 2021-05-20 17:00:00    -0.000784
# 2021-02-18 17:00:00    -0.001857
# 2020-11-12 17:00:00     0.013519
# 2020-08-13 17:00:00    -0.000172
# 2020-05-14 17:00:00     0.003919
# 2020-02-12 17:00:00    -0.001632
#   Symbol  CurrentPrice EarningsDate EarningsTime  AvgAbs1DMove  Implied1DMove  \
# 0   AMAT        318.67   2026-02-12           PM      0.041276            NaN
#
#    Positive1DMoves  ReportedQuarters  HVOL_30D   ATM_VOL
# 0                9                24  0.458591  0.003666

# %%
from datetime import datetime, timedelta
startDate = datetime.today()
endDate = datetime.today()+timedelta(days=2)
minMarketCap = 10000000000
UE = oet.getUpcomingEarnings(startDate, endDate, minMarketCap, universe = None)
#UE.fillna(0, inplace=True)
# Out:
# /Users/grantlau/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:11: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((sigma_2**2*t_2-sigma_1**2*t_1)/(t_2-t_1))
# /Users/grantlau/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:37: RuntimeWarning: invalid value encountered in sqrt
#   sigma_jump = np.sqrt(sigma_T1**2*T1-sigma_diffusive**2*(T1-1))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 5
#       3 endDate = datetime.today()+timedelta(days=2)
#       4 minMarketCap = 10000000000
# ----> 5 UE = oet.getUpcomingEarnings(startDate, endDate, minMarketCap, universe = None)
#       6 #UE.fillna(0, inplace=True)
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:120, in getUpcomingEarnings(startDate, endDate, minMarketCap, universe)
#     118 for index, row in earningsCal.iterrows():
#     119   earningsTime = "AM" if row['time'] == 'time-pre-market' else "PM"
# --> 120   earningsScreens.append(getEarningsScreen(row['symbol'], earningsTime))
#     121 upcomingEarnings = pd.concat(earningsScreens, ignore_index=True)
#     122 return upcomingEarnings
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:91, in getEarningsScreen(ticker, earningsTime, displayEarningsTable)
#      89 nextEarningsIndex = min(range(len(earningsTable.index)), key=lambda i: (earningsTable.index[i].date() < today.date(), abs(earningsTable.index[i] - today)))
#      90 nextEarningsDate = earningsTable.index[nextEarningsIndex]
# ---> 91 implied1DMove = getExpectedDailyMove(yfTicker, nextEarningsDate)
#      92 priceSeries = yfTicker.history(period = '1y')['Close']
#      93 hvol30 = ft.getHistoricalVolatility(priceSeries, days = 30).iloc[-1]
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/OptionsEarningsTools.py:34, in getExpectedDailyMove(yfTicker, nextEarningsDate, startDate)
#      32 expiry_T2 = expiries[expiryIndex_T2]
#      33 callChain_T2, putChain_T2, underlyingInfo_T2 = yfh.getYfOptionChain(yfTicker, expiry_T2)
# ---> 34 sigma_T2 = yfh.getYfImpliedVol(callChain_T2, putChain_T2, underlyingInfo_T2, underlyingInfo_T2['regularMarketPrice'])
#      35 T2 = ct.tradingDaysToExpiry(expiryDate = expiry_T2, startDate = startDate)
#      36 sigma_diffusive = getSigmaForward(sigma_T1, sigma_T2, T1, T2)
#
# File ~/Documents/QuantStuff/Volatility/OptionsEarningsScreen/yfinanceHelper.py:33, in getYfImpliedVol(callChain, putChain, underlyingInfo, strike, interpolation)
#      30 upperStrike = optionChain.loc[optionChain['strike'] > strike, 'strike'].min()
#      32 # Linear interpolation
# ---> 33 lowerIV = optionChain.loc[optionChain['strike'] == lowerStrike, 'impliedVolatility'].values[0]
#      34 upperIV = optionChain.loc[optionChain['strike'] == upperStrike, 'impliedVolatility'].values[0]
#      36 iv = np.interp(strike, [lowerStrike, upperStrike], [lowerIV, upperIV])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
UE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 UE
#
# NameError: name 'UE' is not defined

# %%
UE["ATM_VOL_HVOL_diff"] = (UE["ATM_VOL"]-UE["HVOL_30D"])/UE["HVOL_30D"]
UE.sort_values(by = "rank", ascending = True)

UE["same_day_diff"] = (UE["AvgAbs1DMove"]-UE["Implied1DMove"])
#UE.sort_values(by = "rank_2", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-293b0c6adcbf> in <cell line: 2>()
#       1 UE["ATM_VOL_HVOL_diff"] = (UE["ATM_VOL"]-UE["HVOL_30D"])/UE["HVOL_30D"]
# ----> 2 UE.sort_values(by = "rank", ascending = True)
#       3
#       4 UE["same_day_diff"] = (UE["AvgAbs1DMove"]-UE["Implied1DMove"])
#       5 #UE.sort_values(by = "rank_2", ascending = False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
#    6914             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'rank'

# %%
UE[UE["EarningsTime"] == "PM"]
# Out:
#    Symbol  CurrentPrice EarningsDate EarningsTime  AvgAbs1DMove  \
# 2    VRTX      429.5200   2024-04-29           PM      0.036467
# 4      TM      202.9200   2023-10-31           PM      0.022432
# 6    AMGN      323.1350   2024-02-06           PM      0.029172
# 7     UBS       29.8650   2023-11-06           PM      0.049478
# 9     DIS       97.0125   2024-02-06           PM      0.055876
# 14     UL       49.3050   2023-10-25           PM      0.020946
# 19   CSCO       49.4550   2024-02-14           PM      0.059944
# 20    TTE       64.0400   2023-10-25           PM      0.017259
# 22   AMAT      171.1700   2024-02-15           PM      0.026141
#
#     Implied1DMove  Positive1DMoves  ReportedQuarters  HVOL_30D   ATM_VOL  \
# 2        0.082864                5                 8  0.185709  0.332087
# 4        0.044872               11                 0  0.182781  0.325088
# 6        0.059198                4                 8  0.183579  0.480271
# 7        0.068074                8                11  0.200025  0.449933
# 9        0.071036                4                 8  0.205311  0.615653
# 14            NaN               10                 0  0.129760  0.297310
# 19       0.073752                6                 8  0.163236  0.429151
# 20       0.018995                5                12  0.196674  0.245527
# 22       0.056891                3                 8  0.333340  0.451848
#
#     ATM_VOL_HVOL_diff  rank_order
# 2            0.788215         7.0
# 4            0.778572         6.0
# 6            1.616154        16.0
# 7            1.249391        13.0
# 9            1.998637        22.0
# 14           1.291235        14.0
# 19           1.629022        17.0
# 20           0.248398         4.0
# 22           0.355518         5.0

# %%
UE['rank_order'] = UE['ATM_VOL_HVOL_diff'].rank(method='first', ascending=True)
UE['rank_order_2'] = UE['same_day_diff'].rank(method='first', ascending=True)
UE['average_rank'] = (UE['rank_order'] + UE['rank_order_2']) / 2

UE.sort_values(by = "average_rank", ascending = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'same_day_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-59b53587c735> in <cell line: 2>()
#       1 UE['rank_order'] = UE['ATM_VOL_HVOL_diff'].rank(method='first', ascending=True)
# ----> 2 UE['rank_order_2'] = UE['same_day_diff'].rank(method='first', ascending=True)
#       3 UE['average_rank'] = (UE['rank_order'] + UE['rank_order_2']) / 2
#       4
#       5 UE.sort_values(by = "average_rank", ascending = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'same_day_diff'
